# %% [markdown]
# # Steinpose to AnnData v0.1
# The purpose of this code is to take the outputs of the Steinpose napari plugin (which is itself a combination of Steinbock from the Bodemiller lab, and CellPose for cell segnmentation), and create an AnnData and directory structure compatible with the rest of my code base.

# %% [markdown]
# ### Code

# %%
import imc_import_steinpose

# %%
imc_import_steinpose.cellpose_setup?
# Out:
# Signature:
# imc_import_steinpose.cellpose_setup(
#     cellpose_folder='',
#     intensities_folder='intensities',
#     masks_folder='masks',
#     images_folder='img',
#     image_channel_folder='Images',
#     regionprops_folder='regionprops',
#     regionsprops_metrics=['area'],
#     dictionary='dictionary.csv',
#     normalisation=['q0.999'],
#     store_package_versions=True,
# )
# Docstring: Takes a Steinpose directory structure and returns an AnnData object
# File:      d:\programming\24 01 - abdullah steinpose\imc_import_steinpose.py
# Type:      function

# %%
adata = imc_import_steinpose.cellpose_setup()

# %%
# Save AnnData object ready for next notebook
adata.write('adata_freshimport.h5ad')
